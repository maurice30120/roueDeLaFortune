# %% [markdown]
# # Démo (Colab)
#
# Ce notebook clone le repo puis exécute:
# - `assign` sans animation
# - `complete` (affiche seulement les personnes sélectionnées)

# %%
# %%bash
# set -euo pipefail
# cd /content
# if [ ! -d roueDeLaFortune ]; then
#   git clone https://github.com/maurice30120/roueDeLaFortune.git roueDeLaFortune
# fi
# cd roueDeLaFortune
# python3 -m pip install -r requirements.txt
# Out:
# Requirement already satisfied: rich>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.0.0->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.0.0->-r requirements.txt (line 1)) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->-r requirements.txt (line 1)) (0.1.2)
# Cloning into 'roueDeLaFortune'...

# %%
# %cd /content/roueDeLaFortune
# Out:
# /content/roueDeLaFortune

# %%
# !python3 app.py assign --force
# Out:
# ╔═══════════════════════════════════════════════╗
# ║                                               ║
# ║        🎰  ROUE DE LA FORTUNE  🎰           ║
# ║          Répartition des corvées              ║
# ║                                               ║
# ╚═══════════════════════════════════════════════╝
#
# 📅 Date : 2026-02-03
# 🎯 Corvée : Talomi x3
#
#
# ✓ Talomi          → Damien
#    .-""""-.
#   /  _  _  \
#  |  (o)(o)  |
#  |   .__.   |
#   \  ----  /
#    `-.__.-`
# 🛡️ Damien est à l'abri. Tour annulé, on relance.
#
# ✓ Talomi          → Morgan
#
# ✓ Talomi          → Brice
#
# ✓ Talomi          → Cyril
#
# ══════════════════════════════════════════════════
# ✨ Répartition terminée avec succès ! ✨
# ══════════════════════════════════════════════════

# %%
# !python3 app.py complete
# Out:
# ✓ Personne(s) sélectionnée(s) :
# Damien
# Tamish
# Morgan
# Xavier
# Cyril
# Sara
# Brice
# Thomas
