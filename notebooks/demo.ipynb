# %% [markdown]
# # Démo (simple)
#
# - `assign` sans animation
# - `complete` affiche seulement les personnes sélectionnées

# %%
# Se placer à la racine du repo (au cas où le notebook est lancé depuis notebooks/)
import os
from pathlib import Path

repo_root = Path.cwd().resolve()
if not (repo_root / 'app.py').exists():
    repo_root = repo_root.parent
os.chdir(repo_root)
print('cwd:', Path.cwd())
# Out:
# cwd: /Users/dhuyet/Documents/roueDeLaFortune

# %%
# !python3 app.py assign --force
# Out:
# ╔═══════════════════════════════════════════════╗
# ║                                               ║
# ║        🎰  ROUE DE LA FORTUNE  🎰           ║
# ║          Répartition des corvées              ║
# ║                                               ║
# ╚═══════════════════════════════════════════════╝
#
# 📅 Date : 2026-02-03
# 🎯 Corvée : Talomi x3
#
#
# ✓ Talomi          → Cyrilm        → Cyril ✨m..
#
# ✓ Talomi          → Thomasm       → Thomas ✨m.
#
# ✓ Talomi          → Bricem        → Brice ✨m..
#
# ══════════════════════════════════════════════════
# ✨ Répartition terminée avec succès ! ✨
# ══════════════════════════════════════════════════

# %%
# !python3 app.py complete
# Out:
# ✓ Personne(s) sélectionnée(s) :
# Damien
# Tamish
# Morgan
# Xavier
# Cyril
# Sara
# Brice
# Thomas
