# %% [markdown]
# # Roue graphique (notebook/Colab)
#
# Ce notebook exécute `assign_chores` et affiche une vraie roue graphique (matplotlib) qui s'arrête sur l'utilisateur sélectionné.

# %%
# %%bash
# set -euo pipefail
# # Colab: cloner le repo si besoin
# if [ -d /content ]; then
#   cd /content
#   if [ ! -d roueDeLaFortune ]; then
#     git clone https://github.com/maurice30120/roueDeLaFortune.git roueDeLaFortune
#   fi
#   cd roueDeLaFortune
# fi
# python3 -m pip -q install -r requirements.txt
# python3 -m pip -q install matplotlib
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %%
# Se placer à la racine du repo
import os
from pathlib import Path

if Path('/content/roueDeLaFortune').exists():
    os.chdir('/content/roueDeLaFortune')
else:
    # local: si le notebook est lancé depuis notebooks/
    if not Path('app.py').exists() and Path('..').joinpath('app.py').exists():
        os.chdir('..')

print('cwd:', Path.cwd())
# Out:
# cwd: /Users/dhuyet/Documents/roueDeLaFortune

# %%
from chore_manager import assign_chores

# Exemple: 2 fois la vaisselle (roue + arrêt sur l'utilisateur)
assign_chores(count=2, specific_chore='Vaisselle', auto_mode=True, force_mode=True, animate=True)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╔═══════════════════════════════════════════════╗
# ║                                               ║
# ║        🎰  ROUE DE LA FORTUNE  🎰           ║
# ║          Répartition des corvées              ║
# ║                                               ║
# ╚═══════════════════════════════════════════════╝
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ❌ Corvée "Vaisselle" non trouvée dans la configuration.
# Corvées disponibles:
#   • Talomi
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# {'error': 'chore_not_found', 'date': '2026-02-05'}

# %% [markdown]
# ## Complete (CLI)
# La commande `complete` affiche seulement la/les personne(s) sélectionnée(s).

# %%
# !python3 app.py complete
