# %% [markdown]
# # Démo - Roue de la Fortune (Python)
#
# Ce notebook utilise le module `chore_manager` pour exécuter les mêmes actions que la CLI.
# En environnement Jupyter/Colab, les animations sont désactivées par défaut.

# %%
# Setup: allow local imports when running from the notebooks/ folder
from pathlib import Path
import sys

repo_root = Path.cwd().resolve()
if not (repo_root / 'chore_manager').exists():
    repo_root = repo_root.parent

if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

# %%
assign_chores(count=2, specific_chore="Vaisselle", auto_mode=True, force_mode=True, animate=True)

# %% [markdown]
# ## Statut initial

# %%
show_status()

# %% [markdown]
# ## Attribution d'exemple
#
# `animate=True` pour essayer d'afficher les animations dans le notebook.
# (Selon l'environnement, les animations peuvent être limitées.)

# %%
assign_chores(count=2, specific_chore="Vaisselle", auto_mode=True, force_mode=True, animate=False)

# %%
show_status()

# %% [markdown]
# ## Marquer comme terminé

# %%
complete_chore("Vaisselle", all_mode=True)

# %% [markdown]
# ## Totem d'immunité
#
# Exemples (décommente selon vos besoins) :

# %%
show_totem_status()
# add_totem_user("Alice")
# add_safe_user("Bob")
# remove_totem_user("Alice")
# remove_safe_user("Bob")
# clear_safe()
# clear_totem()

# %% [markdown]
# ## Réinitialiser (avec avertissement)
#
# Attention : cette action efface l'historique. Décommente si nécessaire.

# %%
# reset(confirm=False)
